# %% [markdown]
# # Classification Algorithm
#
# - The classification algorithm is used to identify the categorical of new observation on the basis of training data
#
# - In classification, a program learns from the given datast or observation and then classifies new observation into a number of classes or groups.
#
# - Such as, Yes or No, 0 or 1, spam or not spam, cat or dog etc. Classes can be xalled as targets/labels or categories.
#
# ##### There are two types of classifications:
#
# - **Binary Classfier:** If the classification problem has only two possible outcomes, then it is called as Binary Classification.
# **Examples:** Spam or Not Spam, Cat ot Dog, etc.
#
# - **Multiclass Classifier:** If a classification problem has more than two outcomes, then it is called as Multi-class Classifier.
# **Example:** Classification of types of crops, Classification of types of music
#
# **Linear Models:**
# - Logistic Regression
# - Support Vector Machine
#
# **Non-Linear Models:**
# - K-Nearest Neighbours
# - SVM
# - Naive Bayes
# - Decision Tree Classification
# - Random Forest Classification

# %% [markdown]
# # Logistic Regression
#
# - Logistic regression is one of the most popular Machine Learning algorithms, which comes under the supervised Learning Technique.
#
# - It is used for predicting the categorical dependent variables using a given set of independent variables.
#
# - Therefore, the outcome must be a categorical or discrete value. It can be either Yes or No, 0 or 1, True or False, etc. but instead of giving the exact values as 0 and 1, it gives the probabilistic values which lie between 0 and 1.
#
# ###### Types of Logistic Regression
#
# **On the basis of the categorical, Logistic Regression can be classified int three types:**
#
# - **Binomial:** In binomial model logistic regression, there can be only two possible types of the dependent variables, such as 0 or 1, Pass or Fail, etc.
#
# - **Multinomial:** Inmultinomial Logistic Regression, there can be 3 or more possible unordered types of the dependent variables, such as "cat", "Dog" or "Sheep".
#
# - **Ordinal:** In ordinal Logistic regression, there can be 3 or more possible ordered types of dependent variables, such as "low", "medium" or "High".

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv(r"/workspaces/Data_Science_Notes/machine_learning/supervised_learning_in_ml/classification/data/Social_Network_Ads.csv")

# %%
dataset.head(5)
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
sns.scatterplot(x ="Age", y = "Purchased", data = dataset, hue = "Purchased")
# Out:
# <Axes: xlabel='Age', ylabel='Purchased'>

# %%
x = dataset[["Age"]]
y = dataset["Purchased"]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 42)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test, y_test)*100
# Out:
# 89.0

# %%
sns.scatterplot(x = "Age", y = "Purchased", data = dataset, hue = "Purchased")
sns.lineplot(x = "Age", y = lr.predict(x) , data = dataset,c = "red")
plt.legend()
plt.show()

# %%
lr.predict([[28]])
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
placement = pd.read_csv(r"/workspaces/Data_Science_Notes/machine_learning/supervised_learning_in_ml/classification/data/placement.csv")

# %%
placement.head(5)
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
placement = placement.drop(columns = "Unnamed: 0")

# %%
placement.head(5)
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
sns.boxplot(x = "cgpa", data = placement)
# Out:
# <Axes: xlabel='cgpa'>

# %%
plt.Figure(figsize = (10, 10))
sns.scatterplot(x = "cgpa", y = "iq",data = placement, hue = 'placement')
plt.show()

# %%
xx = placement.iloc[:,:-1]
yy = placement["placement"]

# %%
from sklearn.model_selection import train_test_split

# %%
xx_train, xx_test, yy_train, yy_test = train_test_split(xx, yy, test_size = 0.25, random_state = 42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr.fit(xx_train,yy_train)
# Out:
# LogisticRegression()

# %%
lr.score(xx_test, yy_test)*100
# Out:
# 88.0

# %%
# !pip install mlxtend
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 6.4 MB/s  0:00:0036m-:--:--
# ...

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(np.array(xx), np.array(yy), clf = lr)
plt.xlabel("cgpa")
plt.ylabel("iq")
plt.show()
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
lr.predict([[7.5, 130]])
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])
