# %% [markdown]
# # Polynomial Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
icecream_data = pd.read_csv('Ice_cream selling data.csv')
icecream_data.head(5)
# Out:
#    Temperature (°C)  Ice Cream Sales (units)
# 0         -4.662263                41.842986
# 1         -4.316559                34.661120
# 2         -4.213985                39.383001
# 3         -3.949661                37.539845
# 4         -3.578554                32.284531

# %%
icecream_data.isnull().sum()
# Out:
# Temperature (°C)           0
# Ice Cream Sales (units)    0
# dtype: int64

# %%
icecream_data.rename(columns={
        'Temperature (°C)': 'temperature',
        'Ice Cream Sales (units)': 'sales'
    }, inplace = True)

# %%
icecream_data.corr()
# Out:
#              temperature     sales
# temperature     1.000000 -0.175184
# sales          -0.175184  1.000000

# %%
sns.scatterplot(x = icecream_data['temperature'], y = icecream_data['sales'])
# Out:
# <Axes: xlabel='temperature', ylabel='sales'>

# %%
x = icecream_data[['temperature']]
y = icecream_data['sales']

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pf = PolynomialFeatures(degree = 2)
pf.fit(x)
# Out:
# PolynomialFeatures()

# %%
x = pf.transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 42)

# %%
from sklearn.linear_model import LinearRegression

# %%
x.ndim
# Out:
# 2

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test, y_test)*100
# Out:
# 86.9722394296994

# %%
prd = lr.predict(x)

# %%
sns.scatterplot(x = icecream_data['temperature'], y = icecream_data['sales'], label = 'org')
plt.plot(icecream_data['temperature'], prd, label = 'regLine', c = 'red')
plt.legend()
plt.show()
