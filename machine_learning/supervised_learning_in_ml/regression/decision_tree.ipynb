# %% [markdown]
# # Decision Tree Using Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv(r"/workspaces/Data_Science_Notes/machine_learning/supervised_learning_in_ml/regression/data/multiple_linear_regression_dataset.csv")
dataset.head(10)
# Out:
#    age  experience  income
# 0   25           1   30450
# 1   30           3   35670
# 2   47           2   31580
# 3   32           5   40130
# 4   43          10   47830
# 5   51           7   41630
# 6   28           5   41340
# 7   33           4   37650
# 8   37           5   40250
# 9   39           8   45150

# %%
sns.pairplot(dataset)
plt.show()

# %%
x = dataset.iloc[:, :-1]
y = dataset["income"]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 42)

# %%
from sklearn.tree import DecisionTreeRegressor, plot_tree

# %%
dtr = DecisionTreeRegressor()
dtr.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
print(dtr.score(x_train, y_train)*100, dtr.score(x_test, y_test)*100)
# Out:
# 100.0 2.3434828758061133

# %%
plot_tree(dtr)
plt.show()

# %%
for i in range(1, 8):
    dtr1 = DecisionTreeRegressor(max_depth = i)
    dtr1.fit(x_train, y_train)
    print(dtr1.score(x_train, y_train)*100, dtr1.score(x_test, y_test)*100, i)
# Out:
# 59.78840112831967 -9.420769214235513 1
# 92.64488039934099 50.67355696705871 2
# 97.41755437176054 57.97722968332357 3
# 99.80332149649037 53.0656476710583 4
# 99.93161195141148 -0.22728939525931136 5
# 100.0 2.3434828758061133 6
# 100.0 57.571820327033095 7
